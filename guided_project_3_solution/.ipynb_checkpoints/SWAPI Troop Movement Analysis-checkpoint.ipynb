# %%
# Install Parquet file requirements
# !pip install pyarrow
# !pip install fastparquet
    
print('Parquet file packages installed.')
# Out:
# Requirement already satisfied: pyarrow in c:\users\wasadmin\anaconda3\lib\site-packages (12.0.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\wasadmin\anaconda3\lib\site-packages (from pyarrow) (1.23.5)
# Requirement already satisfied: fastparquet in c:\users\wasadmin\anaconda3\lib\site-packages (2023.4.0)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\wasadmin\anaconda3\lib\site-packages (from fastparquet) (1.23.5)
# Requirement already satisfied: fsspec in c:\users\wasadmin\anaconda3\lib\site-packages (from fastparquet) (2022.11.0)
# Requirement already satisfied: packaging in c:\users\wasadmin\anaconda3\lib\site-packages (from fastparquet) (22.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\wasadmin\anaconda3\lib\site-packages (from fastparquet) (1.5.3)
# Requirement already satisfied: cramjam>=2.3 in c:\users\wasadmin\anaconda3\lib\site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\wasadmin\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wasadmin\anaconda3\lib\site-packages (from pandas>=1.5.0->fastparquet) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\wasadmin\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)

# %%
import pandas as pd

# Read the raw data CSV file into a pandas DataFrame
df = pd.read_csv('troop_movements.csv')
df.head()
# Out:
#              timestamp  unit_id           unit_type empire_or_resistance  \
# 0  2023-06-14 14:04:43        1  resistance_soldier           resistance
# 1  2023-06-14 14:04:42        2               at-st           resistance
# 2  2023-06-14 14:04:41        3               at-at               empire
# 3  2023-06-14 14:04:40        4  resistance_soldier           resistance
# 4  2023-06-14 14:04:39        5        stormtrooper           resistance
#
#    location_x  location_y  destination_x  destination_y homeworld
# 0           8           8              4              2  Champala
# 1           5           6              8             10     Cerea
# 2           3           9              3             10     Zolan
# 3           5           6              9              2     Naboo
# 4           5          10              2              8  Iridonia

# %%
# Group by 'empire_or_resistence' and count the occurrences
grouped_data = df.groupby(['empire_or_resistance']).size().reset_index(name='count')

# Display the result
print(grouped_data)
# Out:
#   empire_or_resistance  count
# 0               empire    497
# 1           resistance    503

# %%
# Group by 'homeworld' and count the occurrences
grouped_data = df.groupby(['homeworld']).size().reset_index(name='count')

# Display the result
print(grouped_data)
# Out:
#        homeworld  count
# 0       Alderaan     17
# 1    Aleen Minor     27
# 2     Bestine IV     20
# 3          Cerea     21
# 4       Champala     28
# 5      Chandrila     28
# 6   Concord Dawn     27
# 7       Corellia     31
# 8        Dagobah     24
# 9       Dathomir     23
# 10         Dorin     19
# 11        Eriadu     21
# 12   Glee Anselm     28
# 13    Haruun Kal     25
# 14       Iktotch     32
# 15      Iridonia     20
# 16         Kalee     21
# 17      Kashyyyk     25
# 18     Malastare     24
# 19        Mirial     28
# 20      Mon Cala     27
# 21    Muunilinst     20
# 22         Naboo     28
# 23          Ojom     21
# 24       Quermia     19
# 25         Rodia     26
# 26        Ryloth     20
# 27       Serenno     21
# 28         Shili     29
# 29         Skako     23
# 30       Socorro     17
# 31       Stewjon     24
# 32       Sullust     25
# 33      Tatooine     24
# 34       Tholoth     16
# 35      Toydaria     24
# 36     Trandosha     28
# 37       Troiken     23
# 38          Tund     15
# 39        Umbara     27
# 40       Vulpter     24
# 41         Zolan     30

# %%
# Group by 'unit_type' and count the occurrences
grouped_data = df.groupby(['unit_type']).size().reset_index(name='count')

# Display the result
print(grouped_data)
# Out:
#             unit_type  count
# 0               at-at    134
# 1               at-st    147
# 2  resistance_soldier    145
# 3        stormtrooper    151
# 4         tie_fighter    134
# 5        tie_silencer    146
# 6              x-wing    143

# %%
# Add a boolean feature based on 'empire_or_resistance'. Resistance=1 and Empire=0
df['is_resistance'] = df['empire_or_resistance'].apply(lambda x: x == 'resistance')

# Print the updated DataFrame
df.head()
# Out:
#              timestamp  unit_id           unit_type empire_or_resistance  \
# 0  2023-06-14 14:04:43        1  resistance_soldier           resistance
# 1  2023-06-14 14:04:42        2               at-st           resistance
# 2  2023-06-14 14:04:41        3               at-at               empire
# 3  2023-06-14 14:04:40        4  resistance_soldier           resistance
# 4  2023-06-14 14:04:39        5        stormtrooper           resistance
#
#    location_x  location_y  destination_x  destination_y homeworld  \
# 0           8           8              4              2  Champala
# 1           5           6              8             10     Cerea
# 2           3           9              3             10     Zolan
# 3           5           6              9              2     Naboo
# 4           5          10              2              8  Iridonia
#
#    is_resistance
# 0           True
# 1           True
# 2          False
# 3           True
# 4           True

# %%
# Create a bar graph to show empire vs resistance distribution

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Count the occurrences of each value in the "empire_or_resistance" column
empire_resistance_counts = df['empire_or_resistance'].value_counts()

# Create the bar plot using seaborn
sns.barplot(x=empire_resistance_counts.index, y=empire_resistance_counts.values)

# Set the y-axis limits and tick format
plt.ylim(0, 1000)
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))


# Set labels and title
plt.xlabel('Empire or Resistance')
plt.ylabel('Count')
plt.title('Character Count by Empire or Resistance')

# Display the plot
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Select the features and target variable
features = ['homeworld', 'unit_type']
target = 'is_resistance'
X = df[features]  # Features
y = df[target]  # Target variable

# Convert categorical features to numeric using one-hot encoding
X_encoded = pd.get_dummies(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create a decision tree classifier
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate accuracy score
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy score
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.505

# %%
# Select the features and target variable
features = ['homeworld', 'unit_type']
target = 'is_resistance'
X = df[features]  # Features
y = df[target]  # Target variable

# Convert categorical features to numeric using one-hot encoding
X_encoded = pd.get_dummies(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create a decision tree classifier
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Get feature importances
importances = model.feature_importances_

# Create a DataFrame to hold the feature importances
feature_importances = pd.DataFrame({'Feature': X_encoded.columns, 'Importance': importances})

# Sort the DataFrame by importance in descending order
feature_importances = feature_importances.sort_values('Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(8, 6))
plt.bar(feature_importances['Feature'], feature_importances['Importance'])
plt.xticks(rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importances')
plt.show()

# Display the most influential unit_type
most_influential_unit_type = feature_importances.iloc[0]['Feature']
print('Most Influential Unit Type:', most_influential_unit_type)
# Out:
# Most Influential Unit Type: unit_type_resistance_soldier

# %%
import pickle

# Save trained model
with open('trained_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
######################################################################################
# At this point, the model has been trained and saved to disk for use with new datat #
# to be predicted.                                                                   #
######################################################################################

# %%
# load 'real' data and use the model to predict Empire or Resistance
# Read the raw data CSV file into a pandas DataFrame
df10m = pd.read_csv('troop_movements10m.csv')
df10m.head()
# Out:
#              timestamp  unit_id     unit_type  location_x  location_y  \
# 0  2023-06-13 17:33:18        1         at-st         2.0         8.0
# 1  2023-06-13 17:33:17        2  tie_silencer         4.0         4.0
# 2  2023-06-13 17:33:16        3         at-at         0.0         3.0
# 3  2023-06-13 17:33:15        4  tie_silencer         6.0         1.0
# 4  2023-06-13 17:33:14        5   tie_fighter         0.0         4.0
#
#    destination_x  destination_y    homeworld
# 0              1              1  Glee Anselm
# 1              0              1    Trandosha
# 2              6              1     Corellia
# 3              6              9        Shili
# 4              9              6   Muunilinst

# %%
# Find all 'invalid_unit' and replace with unknown
df10m.loc[df10m['unit_type'] == 'invalid_unit', 'unit_type'] = 'unknown'
grouped_data = df10m.groupby(['unit_type']).size().reset_index(name='count')

# Display the result
print(grouped_data)
# Out:
#             unit_type    count
# 0               at-at  1426525
# 1               at-st  1426173
# 2  resistance_soldier  1425774
# 3        stormtrooper  1428291
# 4         tie_fighter  1426809
# 5        tie_silencer  1428016
# 6             unknown    10000
# 7              x-wing  1428412

# %%
# propagate last valid observation forward to next valid for location_x and location_y
df10m[['location_x', 'location_y']] = df[['location_x', 'location_y']].fillna(method='ffill')

# Write the cleaned data to a Parquet file
df10m.to_parquet('cleaned_troop_movements10m.parquet', index=False)

print('Data cleaning complete.')
# Out:
# Data cleaning complete.

# %%
# Load the trained model
with open('trained_model.pkl', 'rb') as file:
    model = pickle.load(file)

# Load clean data from parquet file
df10m = pd.read_parquet('cleaned_troop_movements10m.parquet')
features = ['homeworld', 'unit_type']
new_data = df10m[features]  # Features

# Convert categorical features to numeric using one-hot encoding
new_data_encoded = pd.get_dummies(new_data)

# Assuming you have new data for prediction stored in a pandas DataFrame called 'new_data_encoded'
predictions = model.predict(new_data_encoded)

# You can use the predictions as desired
# print(predictions)

# %%
df10m['predictions'] = predictions
df10m.head()
